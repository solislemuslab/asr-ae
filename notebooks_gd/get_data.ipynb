# %% [markdown]
# This notebook downloads from the InterPro website all the protein sequences that match a particular PFAM entry.

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/Shareddrives/vae-asr/
# Out:
# Mounted at /content/drive
# /content/drive/Shareddrives/vae-asr

# %%
pfam_acc = "PF00067"
! python scripts/download_tsv.py {pfam_acc}
# Out:
# Adding proteins 1 to 200 to file
# Adding proteins 201 to 400 to file
# Adding proteins 401 to 600 to file
# Adding proteins 601 to 800 to file
# Adding proteins 801 to 1000 to file
# Adding proteins 1001 to 1200 to file
# Adding proteins 1201 to 1400 to file
# Adding proteins 1401 to 1600 to file
# Adding proteins 1601 to 1800 to file
# Adding proteins 1801 to 2000 to file
# Adding proteins 2001 to 2200 to file
# Adding proteins 2201 to 2400 to file
# Adding proteins 2401 to 2600 to file
# Adding proteins 2601 to 2800 to file
# Adding proteins 2801 to 3000 to file
# Adding proteins 3001 to 3200 to file
# Adding proteins 3201 to 3400 to file
# Adding proteins 3401 to 3600 to file
# Adding proteins 3601 to 3800 to file
# Adding proteins 3801 to 4000 to file
# Adding proteins 4001 to 4200 to file
# Adding proteins 4201 to 4400 to file
# Adding proteins 4401 to 4600 to file
# Adding proteins 4601 to 4800 to file
# Adding proteins 4801 to 5000 to file
# ...
